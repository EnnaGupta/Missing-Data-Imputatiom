# %%
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install seaborn
! pip install scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"/content/womissing_mice_area.csv",low_memory=False)
data.loc[data['YEILD/AREA'] == 0]
# Out:
#         Tehsil_name            ST1 STATE_TEHSIL_CODES   Crop     Year  \
# 800      CANNING-II    West Bengal              WB_58  Paddy  2009-10
# 1992       Fatehpur  Uttar Pradesh              UP_48    Pea  2004-05
# 2007   THIRUPPATHUR     Tamil Nadu              TN_40  Paddy  2011-12
# 2226          ATTUR     Tamil Nadu              TN_57  Paddy  2011-12
# 3677      ORATHANAD     Tamil Nadu              TN_26  Paddy  2011-12
# ...             ...            ...                ...    ...      ...
# 13476       Chittur         Kerala              KL_27  Paddy  2007-08
# 13483       Chittur         Kerala              KL_28  Paddy  2007-08
# 13484       Chittur         Kerala              KL_27  Paddy  2011-12
# 14071   PATTUKOTTAI     Tamil Nadu              TN_27  Paddy  2013-14
# 28662   GANGARAMPUR    West Bengal              WB_53  Paddy  2009-10
#
#        Tehsil_Cultivator  Tehsil  Cultivator  Parcel_Plot_Season__PPS_  \
# ...

# %%
df = data[data.Crop == 'Paddy']
df =df[['YEILD/AREA','Year','Area','Season']]
df.sort_values(by=['Year'])
df.head()
# Out:
#    YEILD/AREA     Year  Area  Season
# 0    5.000000  2002-03   0.0       2
# 1   37.500000  2008-09   0.0       1
# 2   26.666667  2004-05   0.0       2
# 3   25.000000  2005-06   0.0       1
# 4   17.478261  2007-08   0.0       1

# %%
df.to_csv('file1.csv')
